# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет Александр! Меня зовут Марат, и я буду твоим ревьюером. Спешу сообщить что все ключевые этапы в работе выполнены,  с задачей тебе удалось справиться. По поводу обращения - в IT сфере принято общаться на «ты» :) Но, если привычней на «вы», дай знать. Как ревьюера моя задача помочь тебе в развитии, дав хорошие советы. Я внимательно посмотрю твой код, ознакомлюсь с твоими выводами и оставлю комментарии. Где то могу предложить небольшие исправление в коде, но ненавязчиво. Где потребуются уточнения, я оставлю много наводящих вопросов. Они помогут тебя с поиском верного решения.
#
# Все мои комментарии размечены по цветам, для лучшего восприятия.
#
# <div class="alert alert-success">Зеленым цветом и 👍, словом «Успех» отмечены особо удачные и элегантные решения, которыми ты можешь гордиться. </div>
#
# <div class="alert alert-warning">Желтым и 🤔, словом «Совет», помечены решения у которых есть альтернативные решения, более оптимальные. Ты можешь найти их сразу и доработать проект, или отложить это на потом, для будущих проектах. Проект будет принят и без их доработки. </div>
#
# <div class="alert alert-danger"> Красным цветом и значком ❌, словом «Ошибка» помечу твои решения, на которые стоит обратить внимание прежде всего. После их доработки проект будет принят. </div>
#
# Залог успеха - работа сообща, взаимное уважение и работа в диалоге. Поэтому, помечай свои ответные комментарии на мои реплики заметным цветом или курсивом, так мне будет легче их отслеживать. Пожалуйста, не изменяй и не удаляй мои комментарии. Все это поможет выполнить повторную проверку быстрей.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="5"><b>Комментарий Студента</b></font>
#
# Марат, привет! 👋
#
# Спасибо, что посмотрел мой проект. Ниже я постарался ответить на замечания и исправить ошибки
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Привет Александр!
#
#
#
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Умножение-матриц" data-toc-modified-id="Умножение-матриц-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Умножение матриц</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Признаки-умножают-на-обратимую-матрицу.-Изменится-ли-качество-линейной-регрессии?" data-toc-modified-id="Признаки-умножают-на-обратимую-матрицу.-Изменится-ли-качество-линейной-регрессии?-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Признаки умножают на обратимую матрицу. Изменится ли качество линейной регрессии?</a></span></li></ul></li></ul></li><li><span><a href="#Алгоритм-преобразования" data-toc-modified-id="Алгоритм-преобразования-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Алгоритм преобразования</a></span></li><li><span><a href="#Проверка-алгоритма" data-toc-modified-id="Проверка-алгоритма-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка алгоритма</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Защита персональных данных клиентов

# %% [markdown]
# Вам нужно защитить данные клиентов страховой компании «Хоть потоп». Разработайте такой метод преобразования данных, чтобы по ним было сложно восстановить персональную информацию. Обоснуйте корректность его работы.
#
# Нужно защитить данные, чтобы при преобразовании качество моделей машинного обучения не ухудшилось. Подбирать наилучшую модель не требуется.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех 👍:
#
#
# Вступление в работу очень важно, так человек, который смотрит твой проект (и на работе в том числе) будет сразу введен в курс дела.
#
#
#
#
#
# </div>

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# ## Загрузка данных

# %%
try:
    data = pd.read_csv('/datasets/insurance.csv')
except:
    data = pd.read_csv('insurance.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Пол                5000 non-null   int64
#  1   Возраст            5000 non-null   float64
#  2   Зарплата           5000 non-null   float64
#  3   Члены семьи        5000 non-null   int64
#  4   Страховые выплаты  5000 non-null   int64
# dtypes: float64(2), int64(3)
# memory usage: 195.4 KB

# %% [markdown]
# Явных пропусков нет, типы данных численные

# %%
data.head()
# Out:
#    Пол  Возраст  Зарплата  Члены семьи  Страховые выплаты
# 0    1     41.0   49600.0            1                  0
# 1    0     46.0   38000.0            1                  1
# 2    0     29.0   21000.0            0                  0
# 3    0     21.0   41700.0            2                  0
# 4    1     28.0   26100.0            0                  0

# %%
data.describe()
# Out:
#                Пол      Возраст      Зарплата  Члены семьи  Страховые выплаты
# count  5000.000000  5000.000000   5000.000000  5000.000000        5000.000000
# mean      0.499000    30.952800  39916.360000     1.194200           0.148000
# std       0.500049     8.440807   9900.083569     1.091387           0.463183
# min       0.000000    18.000000   5300.000000     0.000000           0.000000
# 25%       0.000000    24.000000  33300.000000     0.000000           0.000000
# 50%       0.000000    30.000000  40200.000000     1.000000           0.000000
# 75%       1.000000    37.000000  46600.000000     2.000000           0.000000
# max       1.000000    65.000000  79000.000000     6.000000           5.000000

# %% [markdown]
# Если смотреть по этому описанию, то данные выглядят адекватно: условано, нет людей с возрастом в 1000 лет, отрицательных зарплат и так далее

# %% [markdown]
# Тут сразу отделим целевую переменную `Страховые выплаты` и все остальные признаки

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех 👍:
#
# EDA проведено.
#
#
# <div class="alert alert-warning">
#
#
# Совет 🤔:
#
#
# - Кроме того можно посмотреть на корреляцию признаков. Известно ли тебе понятие мультиколлиниарность, и две причины почему на мультиколлинеарность было особенно интересно посмотреть в данном проекте?

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="5"><b>Комментарий Студента</b></font>
#
# Мультиколлинеарность это, вроде, когда в матрице есть линейно зависимые признаки.
#
# Про две причины я думаю, что если есть ЛЗ признаки, то у нас просто не будет обратной матрицы для $(X^T X)^{-1}$, потому что там делится на определитель, а он будет нулем. Но я это проверил).
#
# А про вторую точно не знаю, но я вычитал, что тоже с определителем связано. То есть если есть сильная корреляция  между признаками, то определитель будет не строгий ноль, а будет стремиться к нулю. Ну а если делить на бесконечно малое число, то получится бесконечно большое и веса будут огромные.
#
# Первое я проверял, а  вот второе не посмотрел - сделаем сейчас)
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Совет:
#
#
#
#
# В случае высокой корреляции матрица $𝑋^𝑇*𝑋$  близка к вырожденной, как результат чувствительность к малейшему изменению входных данных, приводящая к сильному изменению весов модели, вот остюда и переобучение и  теряется интерпретируемость.
#
#
#
#
# А вот почему это вдвойне интересно для нашего проекта:
#
#
#
#
# - мультиколлиниарность проблема линейных моделей (как в нашем проекте). "Деревянные" модели (RF, DT) устойчивы к мультиколлинеарности, а кластеризация тоже почти не зависит от линейных зависимостей.
#
#
#
#
# -  существует один аспект - как мы находим параметры модели. Найти можно оптимизационно (99% задач в машинном обучении, это когда мы перебираем параметры, ища такие, при которых ошибка минимальная) или аналитически (как в этом проекте - мы решаем по формуле, напрямую). Так вот, когда мы решаем задачу оптимизационо, мультиколлинеарность не вызывает переобучение, потому что есть регуляризация при переборе параметров, а когда мы решаем аналитически проблема переобучения существует.
#
#
#
# Вот поэтому для данного проекта было еще важнее посмотреть на мультиплинеальность
#
#
#
#
# Вот что я имел в виду )

# %%
data.iloc[:, :-1].corr()
# Out:
#                   Пол   Возраст  Зарплата  Члены семьи
# Пол          1.000000  0.002074  0.014910    -0.008991
# Возраст      0.002074  1.000000 -0.019093    -0.006692
# Зарплата     0.014910 -0.019093  1.000000    -0.030296
# Члены семьи -0.008991 -0.006692 -0.030296     1.000000

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="5"><b>Комментарий Студента</b></font>
#
# Получается, что в данном случае мультиколлинеарности между признаками нет
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍
#
#
#
#
# </div>

# %% [markdown]
# ## Умножение матриц

# %% [markdown]
# В этом задании вы можете записывать формулы в *Jupyter Notebook.*
#
# Чтобы записать формулу внутри текста, окружите её символами доллара \\$; если снаружи —  двойными символами \\$\\$. Эти формулы записываются на языке вёрстки *LaTeX.*
#
# Для примера мы записали формулы линейной регрессии. Можете их скопировать и отредактировать, чтобы решить задачу.
#
# Работать в *LaTeX* необязательно.

# %% [markdown]
# Обозначения:
#
# - $X$ — матрица признаков (нулевой столбец состоит из единиц)
#
# - $y$ — вектор целевого признака
#
# - $P$ — матрица, на которую умножаются признаки
#
# - $w$ — вектор весов линейной регрессии (нулевой элемент равен сдвигу)

# %% [markdown]
# Предсказания:
#
# $$
# a = Xw
# $$
#
# Задача обучения:
#
# $$
# w = \arg\min_w MSE(Xw, y)
# $$
#
# Формула обучения:
#
# $$
# w = (X^T X)^{-1} X^T y
# $$

# %% [markdown]
# #### Признаки умножают на обратимую матрицу. Изменится ли качество линейной регрессии?

# %% [markdown]
# **Ответ:** Думаю, что нет
#
# **Обоснование:** Пусть домножение $\tilde{X} = XP$ приводит к изменению предсказаний. Тогда
# $\tilde{y} = \tilde{X}\tilde{w}$ - новые предсказания и должно выполняться
#
# $$y \neq \tilde{y}$$
#
# Также формула обучения изменится следующим образом  $\tilde{w} = (\tilde{X}^T \tilde{X})^{-1} \tilde{X}^T y$. Распишем формулу для новых предсказаний
#
#
# $$
# \tilde{y} = \tilde{X}\tilde{w} = \\
# =\tilde{X}(\tilde{X}^T \tilde{X})^{-1} \tilde{X}^T y = \\
# = XP ((XP)^T(XP))^{-1}(XP)^Ty = \\
# = XP (XP)^{-1} ((XP)^T)^{-1}P^TX^Ty = \\
# = X \left[P P^{-1}\right] X^{-1} (X^T)^{-1} \left[(P^T)^{-1} P^T \right] X^Ty = \\
# = \left[X X^{-1}\right] \left[(X^T)^{-1} X^T \right]y = y
# $$
#
# Получается, что домножение признаков на обратимую матрицу не должно менять качество.
#
#
# Теперь посмотрим как связаны параметры линейной регрессии в исходной задаче и преобразованной, пользуясь полученным результатом.
#
# \begin{cases}
#       y = X w & \text{исходная задача}\\
#       \tilde{y} = \tilde{X} \tilde{w} & \text{преобразованная задача}\\
# \end{cases}
# Зная, что $y = \tilde{y}$ и $\tilde{X} = XP$, тогда можно записать
#
# $$Xw = \tilde{X}\tilde{w}$$
# $$Xw = XP\tilde{w}$$
# $$X^{-1}Xw = X^{-1}XP\tilde{w}$$
#
# Получается, что $w = P\tilde{w}$ или $\tilde{w}= P^{-1}w$

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка ❌:
#
#
#
#
# Направление твоего доказательства верное - берем формулу, подставляем, немножко математической магии: открываем скобки, сокращаем итп итд, как в обычной арифметике и вуаля! Вообще тут много аналогий:  в "мире матриц" умножив единичную матрица на вектор или матрицу получаем тот же самый вектор или матрицу, в "мире цифр" это как умножив число на 1, получить тоже самое число. Если умножить матрицу на обратную ей матрицу получаем единичную матрицу, точно также если умножить число на обратное ей число получаем единицу. Но есть особенности пробразований в "мире матриц" которые надо учитывать: обратная матрица существует только у квадратной матрицы, поэтому:
#
# $$
# (AB)^{-1} = B^{-1} A^{-1}
# $$
#
# только когда у нас A и B квадратные, Может когда то в линейную алгебру введут "мнимые матрицы", по подобию "мнимых чисел" )) Но пока не ввели, поэтому перепрыгивать через этот момент не можем, это как на ноль делить
#
#
# А $X$ не квадратная матрица и $ XP $ не дает нам  квадратную матрицу (размерность $X$ 5000на4, размерность $P$ 4на4, значит если перемножить $XP$  получим мтарицу 5000на4 - не квадратная матрица), а если так, то обратной матрицы у ней нет, "делим на 0".
#
#
# И маленькая подсказка, найди тут:
#
# $$
# ((XP)^T XP)^{-1}
# $$
#
#
# три квадратные матрицы.
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
#
#
#
#
#
# Есть ещё один способ доказательства   когда мы берём
#
#
# $$
# w = \arg\min_w MSE(Xw, y)
# $$
#
#
# и
#
# $$
# w_P = \arg\min_w MSE(XPw_p, y)
# $$
#
#
# И делая  замену    w_p, видим что задача
#
# $$
# \arg\min_w MSE(XPw_p, y)
# $$
#
# сводится к
#
#
# $$
# \arg\min_w MSE(Xw, y)
# $$
#
#
# Осталось только догадаться какую замену мы делаем.  Можешь попробовать решить и таким способом
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="5"><b>Комментарий Студента</b></font>
#
# Да, тут я увлекся немного) Согласен, так неправильно
#
# Нужно чуть-чуть по-другому скобки раскрывать (Спасибо за подсказку ;))
# $$
# \tilde{y} = \tilde{X}\tilde{w} = \\
# =\tilde{X}(\tilde{X}^T \tilde{X})^{-1} \tilde{X}^T y = \\
# = XP ((XP)^T(XP))^{-1}(XP)^Ty = \\
# = XP(P^T X^T X P )^{-1} P^TX^T y = \\
# = XP \left[((P^T X^T X) P)^{-1}\right] P^TX^T y = \\
# = XP \left[P^{-1} (P^T X^T X)^{-1}\right] P^TX^T y = \\
# = X \left[PP^{-1}\right] \left[ (P^T) (X^T X))^{-1}\right] P^TX^T y = \\
# = X  \left[ (P^T) (X^T X))^{-1}\right] P^TX^T y = \\
# = X (X^T X)^{-1} \left[(P^T)^{-1} P^T \right] X^T y = \\
# = X \left[(X^T X)^{-1} X^T y\right] = \\
# = X w = y
# $$
#
# Вот так честно должно быть)
#
# Для вывода связи между параметрами вывод почти такой же. Так же расписывается выражение для $\tilde{w}$ только без умножения на $\tilde{X}$
# $$
# \tilde{w} = (\tilde{X}^T \tilde{X})^{-1} \tilde{X}^T y = \\
# = ((XP)^T(XP))^{-1}(XP)^Ty = \\
# = (P^T X^T X P )^{-1} P^TX^T y = \\
# = \left[((P^T X^T X) P)^{-1}\right] P^TX^T y = \\
# =  \left[P^{-1} (P^T X^T X)^{-1}\right] P^TX^T y = \\
# = P^{-1} \left[ (P^T) (X^T X))^{-1}\right] P^TX^T y = \\
# = P^{-1} \left[ (P^T) (X^T X))^{-1}\right] P^TX^T y = \\
# = P^{-1} (X^T X)^{-1} \left[(P^T)^{-1} P^T \right] X^T y = \\
# = P^{-1} \left[(X^T X)^{-1} X^T y\right] = \\
# = P^{-1} w
# $$
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Так верно
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="5"><b>Комментарий Студента</b></font>
#
# Во втором доказательстве, я правильно понял, что нужно,  по сути, вот сюда
# $$
# \arg\min_w MSE(XPw_p, y)
# $$
# также подставить выражение для $w_p$ и упростить?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Да, самое короткое решение )
#
#
#
#
# </div>

# %% [markdown]
# ## Алгоритм преобразования

# %% [markdown]
# Используя результат предыдущего пункта, можно зашифровать данные следующим образом

# %% [markdown]
# **Алгоритм**
#
# 1. Построить обратимую матрицу $P$ размером $[M \times M]$, $M$ - количество признаков
# 2. Домножить признаки на данную матрицу. Что приведет к искажению значений, но не повлияет на качество модели

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех 👍:
#
#
# Принято

# %% [markdown]
# **Обоснование**
#
# Тут не совсем понял, что нужно обосновать. Доказательство уже есть в пункте выше

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
# Это для случая если студенты используют что-то дополнительно
# </div>

# %% [markdown]
# ## Проверка алгоритма

# %% [markdown]
# Проверка будет заключаться в сравнении показаний `R2` метрики для исходного алгоритма и для зашифрованного.

# %% [markdown]
# Создадим матрицу $P$, зафиксировав генератор случайных чисел для воспроизводимости результата

# %%
np.random.seed(4)
P = np.random.random_sample(size=(X.shape[1], X.shape[1]))

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет 🤔:
#
#
# - Вместо np.random.seed(4), можно здесь было сделать похитрей - генерирум матрицу пока не получим обратимную и наш код  гарантированно полностью отработает. Добиться этого можно например так:
#
#
#
#     def get_rand_matrix():
#         det = 0
#         while det == 0:
#             matrix = np.random.normal(size=(data.shape[1], data.shape[1]))
#             det = np.linalg.det(matrix)
#         return matrix
#
# C помощью рекурсии
#
#     def func(dim):
#         transform_matrix = np.random.rand(dim, dim)
#         try:
#             inv = np.linalg.inv(transform_matrix)
#             return transform_matrix, inv
#         except:
#             func(dim)

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="5"><b>Комментарий Студента</b></font>
#
# Ну да, с функцией поприличнее выглядит. У меня просто с первого раза совпало, я и оставил)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Поприличнее )
#
#
#
#
# </div>

# %% [markdown]
# Функция `test_algorithm` делает следующее:
# 1. Делит подаваемые признаки и целевую переменную на тестовую и тренировочную выборки с соотношением `test_size`
# 2. Строит модель линейной регрессии на тренировочной выборке
# 3. Делает предсказания для тестовых данных
# 4. Выдает значение `R2` метрики

# %%
def test_algorithm(X, y, test_size, seed):
    train_features, test_features, train_target, test_target = train_test_split(X, y, test_size=test_size, random_state=seed)
    model = LinearRegression()
    model.fit(train_features, train_target)
    y_predict = model.predict(test_features)
    return r2_score(test_target, y_predict)

# %% [markdown]
# Проверим алгоритм, запустив `test_algorithm` для исходных и преобразованных данных

# %%
print(f"R2 score initial: {test_algorithm(X, y, 0.3, 4):.8f}")
print(f"R2 score encoded: {test_algorithm(np.dot(X, P), y, 0.3, 4):.8f}")
# Out:
# R2 score initial: 0.40840874
# R2 score encoded: 0.40840874

# %% [markdown]
# Значение коэффициента детерминации получилось не очень хорошим, но его оптимизация и не была целью проекта. Главное, что значения для исходных данных и для зашифрованных одинаковые

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех 👍:
#
# Все сошлось. Отдельный плюс за:
#
#
# - универсальность кода: код отработает для любой размерности матрицы обьект-признак
#
#
#
#
# - использование train_test_split - все правильно, помним о стандартах ML при моделировании

# %% [markdown]
# ## Вывод
#
# В данном проекте был предложен алгоритм зашифровки данных клиентов без потери предсказательной способности линейной модели

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
# Александр, было бы замечательно, в конце немножко о данных, работе с ними, моделировании и полученных результатах, доказательствах. Это важно потому что когда проект захочет посмотреть будущий работодатель (или начальник), у него может не быть времени на подробный разбор кода. Вероятнее всего он бегло просмотрит код, а из общего вывода захочет получить представление о всей работе. Вырабатывай рефлексы правильного формления проектов )
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# <font size="5"><b>Комментарий Студента</b></font>
#
# Расширил вывод
#
# <font size="4"><b>Вывод</b></font>
#
# В данном проекте нам были предоставлены персональные сведения о пользователях страховой компании «Хоть потоп». Для сохранности персональных данных клиентов был предложен алгоритм зашифровки, который не вносит искажений в предсказательную способность линейной модели. Алгоритм тестировался через коэффициента детерминации, значение которого полностью совпало для моделей, построенных на исходных и зашифрованных данных
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Так поприличнее )
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
# У тебя старательно выполненная работа, все четко, осмысленно. Отмечаю уровень твоей программистской подготовки.
#
#
#
#
#
# Я оставил небольшие советы и вопросики (если есть время и желание можешь воспользоваться/ответить)
#
#
#
# Обязательное к исправлению:
#
#
#
#
# - дорабатываем теоретическое доказательство, с учетом моих комментариев
#
#
#
#
# Жду исправлений, для принятия проекта. Если какие то вопросы, то сразу спрашивай )
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Спасибо за работу!
#
#
#
#
# Красного нет,  значит все, пора принимать) Надеюсь мои советы и вопросики были полезны и в копилочку знаний упало что то новое, а проект стал лучше, и симпатичней.
#
#
# Отличная работа Александр. Желаю успехов в дальнейшей учебе!
#
#
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
#
#
# На мой взгляд проект очень необычный, выделяющийся из остальных проектов потому что касается раздела математики лежащей в основе машинного обучения  (помимо производных, матанализа и теории вероятности с матстатистикой). Если в дальнейшем ты углубишься в изучении нейростетей, то понимание линейной алгебры будет очень полезным, потому что, по сути, все нейросети - это перемножение матриц и Линейная алгебра даёт очень компактный способ записи того что происходит в нейросетях.
#
#
#
# Возможно будет полезно:
#
#
#
#
# - Если хочешь посмотреть вообще про линейную алгебру и матрицы, то мне нравится  вот это [видео](https://www.youtube.com/watch?v=RNTRYicPvWQ&list=PLVjLpKXnAGLXPaS7FRBjd5yZeXwJxZil2), рассказывается по существу и увлекательно.
#
#
# - по применению криптографии в машинном обучении на английском: [тут](https://www.cs.cmu.edu/~rjhall/JOS_revised_May_31a.pdf)
